# %% [markdown]
# # Explore here
#
# It's recommended to use this notebook for exploration purposes.

# %%
pip install pandas requests lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/vscode/.local/lib/python3.11/site-packages (3.0.0)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.11/site-packages (2.27.1)
# Requirement already satisfied: lxml in /home/vscode/.local/lib/python3.11/site-packages (6.0.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/vscode/.local/lib/python3.11/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from requests) (2026.1.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from requests) (3.11)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
url = "https://en.wikipedia.org/wiki/List_of_Spotify_streaming_records"

headers = {
    "User-Agent": "Mozilla/5.0 (compatible; DataScienceProject/1.0; +https://example.com)"
}

response = requests.get(url, headers=headers)

response.raise_for_status()

print("Status:", response.status_code)
# Out:
# Status: 200

# %%
html = io.StringIO(response.text)

tables = pd.read_html(html)
print(f"{len(tables)} tables were found.")
# Out:
# 26 tables were found.

# %%
df = tables[0]  # Extract the first table from the 27 found
df.head()  # Display the first 5 rows
# Out:
#   Rank               Song                 Artist(s) Streams (billions)  \
# 0    1  "Blinding Lights"                The Weeknd              5.286
# 1    2     "Shape of You"                Ed Sheeran              4.777
# 2    3  "Sweater Weather"         The Neighbourhood              4.393
# 3    4          "Starboy"  The Weeknd and Daft Punk              4.374
# 4    5        "As It Was"              Harry Styles              4.256
#
#         Release date Ref.
# 0   29 November 2019  [1]
# 1     6 January 2017  [2]
# 2    3 December 2012  [3]
# 3  21 September 2016  [4]
# 4       1 April 2022  [5]

# %%
df.columns
# Out:
# Index(['Rank', 'Song', 'Artist(s)', 'Streams (billions)', 'Release date',
#        'Ref.'],
#       dtype='str')

# %%
df
# Out:
#                        Rank                    Song                 Artist(s)  \
# 0                         1       "Blinding Lights"                The Weeknd
# 1                         2          "Shape of You"                Ed Sheeran
# 2                         3       "Sweater Weather"         The Neighbourhood
# 3                         4               "Starboy"  The Weeknd and Daft Punk
# 4                         5             "As It Was"              Harry Styles
# ..                      ...                     ...                       ...
# 96                       97                "Dreams"             Fleetwood Mac
# 97                       98            "Sicko Mode"    Travis Scott and Drake
# 98                       99           "Billie Jean"           Michael Jackson
# 99                      100      "Someone Like You"                     Adele
# 100  As of 15 February 2026  As of 15 February 2026    As of 15 February 2026
#
#          Streams (billions)            Release date                    Ref.
# 0                     5.286        29 November 2019                     [1]
# 1                     4.777          6 January 2017                     [2]
# 2                     4.393         3 December 2012                     [3]
# 3                     4.374       21 September 2016                     [4]
# 4                     4.256            1 April 2022                     [5]
# ..                      ...                     ...                     ...
# 96                    2.554         4 February 1977                    [97]
# 97                    2.535          21 August 2018                    [98]
# 98                    2.532        29 November 1982                     NaN
# 99                    2.528         24 January 2011                    [99]
# 100  As of 15 February 2026  As of 15 February 2026  As of 15 February 2026
#
# [101 rows x 6 columns]

# %%
df = df.drop(100)
df
# Out:
#    Rank                Song                 Artist(s) Streams (billions)  \
# 0     1   "Blinding Lights"                The Weeknd              5.286
# 1     2      "Shape of You"                Ed Sheeran              4.777
# 2     3   "Sweater Weather"         The Neighbourhood              4.393
# 3     4           "Starboy"  The Weeknd and Daft Punk              4.374
# 4     5         "As It Was"              Harry Styles              4.256
# ..  ...                 ...                       ...                ...
# 95   96           "Happier"   Marshmello and Bastille              2.558
# 96   97            "Dreams"             Fleetwood Mac              2.554
# 97   98        "Sicko Mode"    Travis Scott and Drake              2.535
# 98   99       "Billie Jean"           Michael Jackson              2.532
# 99  100  "Someone Like You"                     Adele              2.528
#
#          Release date  Ref.
# 0    29 November 2019   [1]
# 1      6 January 2017   [2]
# 2     3 December 2012   [3]
# 3   21 September 2016   [4]
# 4        1 April 2022   [5]
# ..                ...   ...
# 95     16 August 2018  [96]
# 96    4 February 1977  [97]
# 97     21 August 2018  [98]
# 98   29 November 1982   NaN
# 99    24 January 2011  [99]
#
# [100 rows x 6 columns]

# %%
df["Release date"] = pd.to_datetime(df["Release date"], errors="coerce")
df["Streams (billions)"] = df["Streams (billions)"].astype(float)
df
# Out:
#    Rank                Song                 Artist(s)  Streams (billions)  \
# 0     1   "Blinding Lights"                The Weeknd               5.286
# 1     2      "Shape of You"                Ed Sheeran               4.777
# 2     3   "Sweater Weather"         The Neighbourhood               4.393
# 3     4           "Starboy"  The Weeknd and Daft Punk               4.374
# 4     5         "As It Was"              Harry Styles               4.256
# ..  ...                 ...                       ...                 ...
# 95   96           "Happier"   Marshmello and Bastille               2.558
# 96   97            "Dreams"             Fleetwood Mac               2.554
# 97   98        "Sicko Mode"    Travis Scott and Drake               2.535
# 98   99       "Billie Jean"           Michael Jackson               2.532
# 99  100  "Someone Like You"                     Adele               2.528
#
#    Release date  Ref.
# 0    2019-11-29   [1]
# 1    2017-01-06   [2]
# 2    2012-12-03   [3]
# 3    2016-09-21   [4]
# 4    2022-04-01   [5]
# ..          ...   ...
# 95   2018-08-16  [96]
# 96   1977-02-04  [97]
# 97   2018-08-21  [98]
# 98   1982-11-29   NaN
# 99   2011-01-24  [99]
#
# [100 rows x 6 columns]

# %%
conn = sqlite3.connect("spotify_top_songs.db")

# %%
df.to_sql("most_streamed", conn, if_exists="replace", index=False)
cursor = conn.cursor()

# %%
cursor.execute("SELECT COUNT(*) FROM most_streamed")
print("Rows inserted:", cursor.fetchone()[0])

conn.commit()
# Out:
# Rows inserted: 100

# %%
df
# Out:
#    Rank                Song                 Artist(s)  Streams (billions)  \
# 0     1   "Blinding Lights"                The Weeknd               5.286
# 1     2      "Shape of You"                Ed Sheeran               4.777
# 2     3   "Sweater Weather"         The Neighbourhood               4.393
# 3     4           "Starboy"  The Weeknd and Daft Punk               4.374
# 4     5         "As It Was"              Harry Styles               4.256
# ..  ...                 ...                       ...                 ...
# 95   96           "Happier"   Marshmello and Bastille               2.558
# 96   97            "Dreams"             Fleetwood Mac               2.554
# 97   98        "Sicko Mode"    Travis Scott and Drake               2.535
# 98   99       "Billie Jean"           Michael Jackson               2.532
# 99  100  "Someone Like You"                     Adele               2.528
#
#    Release date  Ref.
# 0    2019-11-29   [1]
# 1    2017-01-06   [2]
# 2    2012-12-03   [3]
# 3    2016-09-21   [4]
# 4    2022-04-01   [5]
# ..          ...   ...
# 95   2018-08-16  [96]
# 96   1977-02-04  [97]
# 97   2018-08-21  [98]
# 98   1982-11-29   NaN
# 99   2011-01-24  [99]
#
# [100 rows x 6 columns]

# %%
import sqlite3

# %%
top_10_df = pd.read_sql("""
    SELECT * 
    FROM most_streamed 
    ORDER BY "Streams (billions)" DESC 
    LIMIT 10
""", conn)

top_10_df
# Out:
#   Rank                 Song                        Artist(s)  \
# 0    1    "Blinding Lights"                       The Weeknd
# 1    2       "Shape of You"                       Ed Sheeran
# 2    3    "Sweater Weather"                The Neighbourhood
# 3    4            "Starboy"         The Weeknd and Daft Punk
# 4    5          "As It Was"                     Harry Styles
# 5    6  "Someone You Loved"                    Lewis Capaldi
# 6    7          "Sunflower"         Post Malone and Swae Lee
# 7    8          "One Dance"       Drake with Wizkid and Kyla
# 8    9            "Perfect"                       Ed Sheeran
# 9   10               "Stay"  The Kid Laroi and Justin Bieber
#
#    Streams (billions)         Release date  Ref.
# 0               5.286  2019-11-29 00:00:00   [1]
# 1               4.777  2017-01-06 00:00:00   [2]
# 2               4.393  2012-12-03 00:00:00   [3]
# 3               4.374  2016-09-21 00:00:00   [4]
# 4               4.256  2022-04-01 00:00:00   [5]
# 5               4.229  2018-11-08 00:00:00   [6]
# 6               4.127  2018-10-18 00:00:00   [7]
# 7               4.048  2016-04-05 00:00:00   [8]
# 8               3.836  2017-03-03 00:00:00   [9]
# 9               3.803  2021-07-09 00:00:00  [10]

# %%
conn.close()
